# %%
# %load_ext autoreload

# %%
# %autoreload

# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the dataset
df = pd.read_csv('../dataset/dataset.csv')

phy_features = ['bvpMean', 'bvpSD', 'edaMean', 'edaSD', 'hrMean', 'hrSD', 'tempMean', 'tempSD']
phy_df = df[phy_features + ['score']]

# %%
phy_df.head()
# Out:
#     bvpMean     bvpSD   edaMean       edaSD     hrMean       hrSD   tempMean  \
# 0  0.236196  0.089510  0.025175   75.940602  70.797836  11.891352  30.247661
# 1  9.215965  2.683158  0.004721   45.264730  88.783405   6.785453  32.680684
# 2  0.435311  0.187070  0.001496   53.381157  84.402317  10.955088  29.110469
# 3  2.526160  1.287468  0.020996   44.588299  86.793178  10.971627  31.813990
# 4  0.455791  0.136831  0.066922  128.591755  73.728712   5.598994  29.554968
#
#      tempSD  score
# 0  3.501716    6.5
# 1  0.768958    8.5
# 2  1.402610    5.0
# 3  0.246334    5.5
# 4  0.195491    5.5

# %%
phy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   bvpMean   192 non-null    float64
#  1   bvpSD     192 non-null    float64
#  2   edaMean   192 non-null    float64
#  3   edaSD     192 non-null    float64
#  4   hrMean    192 non-null    float64
#  5   hrSD      192 non-null    float64
#  6   tempMean  192 non-null    float64
#  7   tempSD    192 non-null    float64
#  8   score     192 non-null    float64
# dtypes: float64(9)
# memory usage: 13.6 KB

# %%
phy_df.describe()
# Out:
#           bvpMean       bvpSD     edaMean       edaSD      hrMean        hrSD  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean     1.348202    0.470308    0.011229   64.469009   78.539060    6.808647
# std      1.939888    0.568487    0.023290   28.151290    9.041505    3.736368
# min      0.021980    0.009695   -0.034913   22.180304   61.361945    2.435843
# 25%      0.216028    0.081136   -0.005099   45.261038   71.006312    3.954385
# 50%      0.508091    0.208223    0.003797   54.021791   78.836789    5.268812
# 75%      1.601159    0.838313    0.025349   76.961606   84.842688    8.717657
# max     10.065006    2.751319    0.070623  137.217987  101.137384   17.976566
#
#          tempMean      tempSD       score
# count  192.000000  192.000000  192.000000
# mean    30.805194    0.687507    6.470433
# std      2.265000    0.990735    1.084345
# min     25.615260    0.060969    4.240493
# 25%     29.356536    0.173857    5.616151
# 50%     30.810164    0.264113    6.382098
# 75%     32.235225    0.811892    7.341759
# max     36.394508    4.955262    8.977812

# %%
display(phy_df.corr())
with open('phy_correlation.html', 'w') as f: # make it nicer
    print(phy_df.corr().style.background_gradient()
.to_html(), file=f)
# Out:
#            bvpMean     bvpSD   edaMean     edaSD    hrMean      hrSD  \
# bvpMean   1.000000  0.842067  0.052733 -0.177425  0.257477  0.050161
# bvpSD     0.842067  1.000000 -0.020725 -0.035036  0.371444  0.300480
# edaMean   0.052733 -0.020725  1.000000  0.109468 -0.046491  0.170028
# edaSD    -0.177425 -0.035036  0.109468  1.000000 -0.014802  0.380224
# hrMean    0.257477  0.371444 -0.046491 -0.014802  1.000000  0.315537
# hrSD      0.050161  0.300480  0.170028  0.380224  0.315537  1.000000
# tempMean  0.293943  0.201401  0.037498 -0.221172  0.090725 -0.106168
# tempSD    0.001100  0.143500  0.300802 -0.090351 -0.030285  0.532112
# score     0.381287  0.267164 -0.100880 -0.101515  0.148825  0.061675
#
#           tempMean    tempSD     score
# bvpMean   0.293943  0.001100  0.381287
# bvpSD     0.201401  0.143500  0.267164
# edaMean   0.037498  0.300802 -0.100880
# edaSD    -0.221172 -0.090351 -0.101515
# hrMean    0.090725 -0.030285  0.148825
# hrSD     -0.106168  0.532112  0.061675
# tempMean  1.000000 -0.000443  0.105847
# tempSD   -0.000443  1.000000  0.001474
# score     0.105847  0.001474  1.000000

# %%
figure, axis = plt.subplots(2, 2) 
  
# For Sine Function 
axis[0, 0].plot(X, Y1) 
axis[0, 0].set_title("Sine Function") 
  
# For Cosine Function 
axis[0, 1].plot(X, Y2) 
axis[0, 1].set_title("Cosine Function") 
  
# For Tangent Function 
axis[1, 0].plot(X, Y3) 
axis[1, 0].set_title("Tangent Function") 
  
# For Tanh Function 
axis[1, 1].plot(X, Y4) 
axis[1, 1].set_title("Tanh Function")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <module>
#       1 figure, axis = plt.subplots(2, 2)
#       3 # For Sine Function
# ----> 4 axis[0, 0].plot(X, Y1)
#       5 axis[0, 0].set_title("Sine Function")
#       7 # For Cosine Function
#
# NameError: name 'X' is not defined

# %%
for column in phy_df.columns:
    fig, ax = plt.subplots(figsize=(15,5))
    plt.scatter(phy_df[column], phy_df['score'])
    a, b = np.polyfit(phy_df[column], phy_df['score'],1)
    plt.plot(phy_df[column], a*phy_df[column]+b, linestyle='--',dashes=(3, 3), color='red')
    plt.grid(visible=None)
    plt.xlabel(column)
    plt.ylabel('score')
    plt.title(f'Correlation of {column} and the score')
    plt.show()

# %%
plt.plot([1,2], [2,4])
plt.xlabel
plt.title("foo")

# %%
sns.displot(df['score'], kind="kde")
sns.displot(df['score'])
